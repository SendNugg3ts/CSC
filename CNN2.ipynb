# %%
# !pip install tensorflow
# !pip install scikit-learn
# !pip install matplotlib
# !pip install pandas
# !pip install pydot
# Out:
# Requirement already satisfied: tensorflow in ./venv/lib/python3.10/site-packages (2.12.0)
# Requirement already satisfied: google-pasta>=0.1.1 in ./venv/lib/python3.10/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in ./venv/lib/python3.10/site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: six>=1.12.0 in ./venv/lib/python3.10/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: setuptools in ./venv/lib/python3.10/site-packages (from tensorflow) (59.6.0)
# Requirement already satisfied: absl-py>=1.0.0 in ./venv/lib/python3.10/site-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: termcolor>=1.1.0 in ./venv/lib/python3.10/site-packages (from tensorflow) (2.3.0)
# Requirement already satisfied: flatbuffers>=2.0 in ./venv/lib/python3.10/site-packages (from tensorflow) (23.5.9)
# Requirement already satisfied: typing-extensions>=3.6.6 in ./venv/lib/python3.10/site-packages (from tensorflow) (4.5.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in ./venv/lib/python3.10/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: numpy<1.24,>=1.22 in ./venv/lib/python3.10/site-packages (from tensorflow) (1.23.5)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in ./venv/lib/python3.10/site-packages (from tensorflow) (2.12.3)
# Requirement already satisfied: libclang>=13.0.0 in ./venv/lib/python3.10/site-packages (from tensorflow) (16.0.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in ./venv/lib/python3.10/site-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in ./venv/lib/python3.10/site-packages (from tensorflow) (4.23.1)
# Requirement already satisfied: jax>=0.3.15 in ./venv/lib/python3.10/site-packages (from tensorflow) (0.4.10)
# Requirement already satisfied: packaging in ./venv/lib/python3.10/site-packages (from tensorflow) (23.1)
# Requirement already satisfied: h5py>=2.9.0 in ./venv/lib/python3.10/site-packages (from tensorflow) (3.8.0)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in ./venv/lib/python3.10/site-packages (from tensorflow) (2.12.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in ./venv/lib/python3.10/site-packages (from tensorflow) (0.32.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in ./venv/lib/python3.10/site-packages (from tensorflow) (1.54.2)
# Requirement already satisfied: astunparse>=1.6.0 in ./venv/lib/python3.10/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: keras<2.13,>=2.12.0 in ./venv/lib/python3.10/site-packages (from tensorflow) (2.12.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in ./venv/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow) (0.40.0)
# Requirement already satisfied: scipy>=1.7 in ./venv/lib/python3.10/site-packages (from jax>=0.3.15->tensorflow) (1.10.1)
# Requirement already satisfied: ml-dtypes>=0.1.0 in ./venv/lib/python3.10/site-packages (from jax>=0.3.15->tensorflow) (0.1.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in ./venv/lib/python3.10/site-packages (from tensorboard<2.13,>=2.12->tensorflow) (1.0.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in ./venv/lib/python3.10/site-packages (from tensorboard<2.13,>=2.12->tensorflow) (0.7.0)
# Requirement already satisfied: requests<3,>=2.21.0 in ./venv/lib/python3.10/site-packages (from tensorboard<2.13,>=2.12->tensorflow) (2.30.0)
# Requirement already satisfied: werkzeug>=1.0.1 in ./venv/lib/python3.10/site-packages (from tensorboard<2.13,>=2.12->tensorflow) (2.3.4)
# Requirement already satisfied: google-auth<3,>=1.6.3 in ./venv/lib/python3.10/site-packages (from tensorboard<2.13,>=2.12->tensorflow) (2.18.1)
# Requirement already satisfied: markdown>=2.6.8 in ./venv/lib/python3.10/site-packages (from tensorboard<2.13,>=2.12->tensorflow) (3.4.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in ./venv/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (5.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in ./venv/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (4.9)
# Requirement already satisfied: urllib3<2.0 in ./venv/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (1.26.15)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in ./venv/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (0.3.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in ./venv/lib/python3.10/site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow) (1.3.1)
# Requirement already satisfied: certifi>=2017.4.17 in ./venv/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (2023.5.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./venv/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in ./venv/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (3.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in ./venv/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow) (2.1.2)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in ./venv/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in ./venv/lib/python3.10/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow) (3.2.2)
# Requirement already satisfied: scikit-learn in ./venv/lib/python3.10/site-packages (1.2.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in ./venv/lib/python3.10/site-packages (from scikit-learn) (3.1.0)
# Requirement already satisfied: scipy>=1.3.2 in ./venv/lib/python3.10/site-packages (from scikit-learn) (1.10.1)
# Requirement already satisfied: joblib>=1.1.1 in ./venv/lib/python3.10/site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: numpy>=1.17.3 in ./venv/lib/python3.10/site-packages (from scikit-learn) (1.23.5)
# Requirement already satisfied: matplotlib in ./venv/lib/python3.10/site-packages (3.7.1)
# Requirement already satisfied: packaging>=20.0 in ./venv/lib/python3.10/site-packages (from matplotlib) (23.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./venv/lib/python3.10/site-packages (from matplotlib) (4.39.4)
# Requirement already satisfied: contourpy>=1.0.1 in ./venv/lib/python3.10/site-packages (from matplotlib) (1.0.7)
# Requirement already satisfied: pillow>=6.2.0 in ./venv/lib/python3.10/site-packages (from matplotlib) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in ./venv/lib/python3.10/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in ./venv/lib/python3.10/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: python-dateutil>=2.7 in ./venv/lib/python3.10/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in ./venv/lib/python3.10/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: numpy>=1.20 in ./venv/lib/python3.10/site-packages (from matplotlib) (1.23.5)
# Requirement already satisfied: six>=1.5 in ./venv/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: pandas in ./venv/lib/python3.10/site-packages (2.0.1)
# Requirement already satisfied: pytz>=2020.1 in ./venv/lib/python3.10/site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in ./venv/lib/python3.10/site-packages (from pandas) (1.23.5)
# Requirement already satisfied: tzdata>=2022.1 in ./venv/lib/python3.10/site-packages (from pandas) (2023.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./venv/lib/python3.10/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in ./venv/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: pydot in ./venv/lib/python3.10/site-packages (1.4.2)
# Requirement already satisfied: pyparsing>=2.1.4 in ./venv/lib/python3.10/site-packages (from pydot) (3.0.9)

# %%
import tensorflow as tf
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import TimeSeriesSplit
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, SimpleRNN
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import importlib as imp
import datacleaner
import datetime
imp.reload(datacleaner)

from datacleaner import *
# Out:
# 2023-06-03 22:46:51.122601: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-06-03 22:46:51.165173: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-06-03 22:46:51.165563: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-03 22:46:52.124531: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
np.random.seed(1)
tf.keras.backend.clear_session()

bd = pd.read_csv(r"training_data.csv")

# %%
timesteps = 5 #number of days that make up a sequence
univariate = 1 #number of features used by the model (using incidents to predict incidents)
multisteps = 5 #number of days to forecast – we will forecast the next 5 days
cv_splits = 3 #time series cross validator
epochs = 50
batch_size = 7 #7 sequences of 5 days - which corresponds to a window of 7 days in a batch

# %%
bd.head()
# Out:
#    city_name magnitude_of_delay  delay_in_seconds
# 0  Guimaraes          UNDEFINED                 0  \
# 1  Guimaraes          UNDEFINED               385
# 2  Guimaraes          UNDEFINED                69
# 3  Guimaraes              MAJOR              2297
# 4  Guimaraes          UNDEFINED                 0
#
#                                       affected_roads       record_date
# 0                                                  ,  2021-03-15 23:00  \
# 1                                              N101,  2021-12-25 18:00
# 2                                                  ,  2021-03-12 15:00
# 3  N101,R206,N105,N101,N101,N101,N101,N101,N101,N...  2021-09-29 09:00
# 4                          N101,N101,N101,N101,N101,  2021-06-13 11:00
#
#   luminosity  avg_temperature  avg_atm_pressure  avg_humidity  avg_wind_speed
# 0       DARK             12.0            1013.0          70.0             1.0  \
# 1       DARK             12.0            1007.0          91.0             1.0
# 2      LIGHT             14.0            1025.0          64.0             0.0
# 3      LIGHT             15.0            1028.0          75.0             1.0
# 4      LIGHT             27.0            1020.0          52.0             1.0
#
#    avg_precipitation   avg_rain  incidents
# 0                0.0  Sem Chuva        NaN
# 1                0.0  Sem Chuva        NaN
# 2                0.0  Sem Chuva        Low
# 3                0.0  Sem Chuva  Very_High
# 4                0.0  Sem Chuva       High

# %%
def prepare_data(bd):
    bd = ordernar(bd)
    # bd = RoadsCleaner(bd)
    #bd = data(bd)
    # bd = valores_em_falta(bd)
    # bd = eliminar(bd)
    bd = incidentsNumbers(bd)
    # bd = luminosidade(bd)
    # bd = rainNumbers(bd)
    # bd = delayNumbers(bd)
    bd = removeOutlier(bd)
    bd.index = pd.to_datetime(bd["record_date"], format="%Y-%m-%d %H:%M:00")
    bd = bd[['incidents']]
    return bd

def data_normalization(bd, norm_range=(-1, 1)):
    scaler = MinMaxScaler(feature_range=norm_range)
    bd[['incidents']] = scaler.fit_transform(bd[['incidents']])
    return scaler

def to_supervised(df, timesteps):
    data = df.values
    X, y = list(), list()
    dataset_size = len(data)
    for curr_pos in range(dataset_size):
        input_index = curr_pos + timesteps
        label_index = input_index + 1

        if label_index < dataset_size:
            X.append(data[curr_pos:input_index,:])
            y.append(data[input_index:label_index, 0])
    
    return np.array(X).astype('float32'), np.array(y).astype('float32')

def split_data(bd, perc=10):
    train_idx = np.arange(0, int(len(bd)*(100-perc)/100))
    val_idx = np.arange(int(len(bd)*(100-perc)/100+1), len(bd))
    return train_idx, val_idx

# %%
bd = prepare_data(bd)
# Out:
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor

# %%
bd.head()
# Out:
#                      incidents
# record_date
# 2021-01-16 16:00:00        3.0
# 2021-01-16 18:00:00        2.0
# 2021-01-16 19:00:00        2.0
# 2021-01-16 20:00:00        2.0
# 2021-01-16 21:00:00        3.0

# %%
scaler = data_normalization(bd)
bd.head()
# Out:
#                      incidents
# record_date
# 2021-01-16 16:00:00   0.333333
# 2021-01-16 18:00:00  -0.333333
# 2021-01-16 19:00:00  -0.333333
# 2021-01-16 20:00:00  -0.333333
# 2021-01-16 21:00:00   0.333333

# %%
X, y = to_supervised(bd, timesteps)
X.shape, y.shape
# Out:
# ((4994, 5, 1), (4994, 1))

# %%
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.optimizers import Adam

# %%
def rmse(y_true, y_pred):
    return tf.keras.backend.sqrt(tf.keras.backend.mean(tf.keras.backend.square(y_pred - y_true)))

def build_model(timesteps, features, filters=16, kernel_size=5, pool_size=2):
    #using the Functional API
    inputs = tf.keras.layers.Input(shape=(timesteps, features))
    #microarchitecture
    x = tf.keras.layers.Conv1D(filters=filters, kernel_size=kernel_size,
    activation='relu', data_format='channels_last')(inputs)
    x = tf.keras.layers.AveragePooling1D(pool_size=pool_size,
    data_format='channels_first')(x)
    #last layers
    x = tf.keras.layers.Flatten()(x)
    x = tf.keras.layers.Dense(filters)(x)
    outputs = tf.keras.layers.Dense(1)(x)
    #the model
    cnnModel = tf.keras.Model(inputs=inputs, outputs=outputs, name='cnn_model')
    tf.keras.utils.plot_model(cnnModel, 'cnn.png', show_shapes=True)
    return cnnModel

def plot_learning_curves(history, epochs):
    #accuracies and losses
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    epochs_range = range(epochs)
    #creating figure
    plt.figure(figsize=(8, 8))
    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, acc, label='Training Accuracy')
    plt.plot(epochs_range, val_acc, label='Validation Accuracy')
    plt.legend(loc='lower right')
    plt.title('Training/Validation Accuracy')
    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, loss, label='Training Loss')
    plt.plot(epochs_range, val_loss, label='Validation Loss')
    plt.legend(loc='upper right')
    plt.title('Training/Validation Loss')
    plt.show()

def plot_train_data(data, approach='history'):
    plt.figure(figsize=(8,6))
    if approach == 'history':
        plt.title('Model train vs val loss per Training Split')
        plt.ylabel('Training RMSE (Normalized)')
        plt.xlabel('Epoch')
        for hist, i in zip(data, range(len(data))):  
            plt.subplot(3,1,i+1)      
            plt.plot(hist.epoch, hist.history['loss'])
            plt.plot(hist.epoch, hist.history['val_loss'])
            plt.xlim([0, max(hist.epoch)])  
            plt.legend(['Training split ' + str(i+1) + ' - train loss', 'Training split ' + str(i+1) + ' - val loss'], loc='upper right')
        plt.show()   
    elif approach == 'loss':
        plt.figure(figsize=(6,3))
        plt.plot(range(len(data)), data)
        plt.title('RMSE value per Timeseries split')
        plt.ylabel('Evaluation RMSE')
        plt.xlabel('Timeseries Splits')
        plt.xlim([0, 2])
        plt.ylim([0, (np.amax(data)+2)])
        plt.show()

def compile_and_fit(model, epochs, batch_size):
    #compile
    model.compile(loss = rmse, optimizer = tf.keras.optimizers.Adam(), metrics = ['mae', rmse])
    #fit
    hist_list = list()
    loss_list = list()
    #Time Series Cross Validator
    tscv = TimeSeriesSplit(n_splits=cv_splits)
    for train_index, test_index in tscv.split(X):
        train_idx, val_idx = split_data(train_index, perc=10) #further split into training and validation sets
        #build data
        X_train, y_train = X[train_idx], y[train_idx]
        X_val, y_val = X[val_idx], y[val_idx]
        X_test, y_test = X[test_index], y[test_index]
        history = model.fit(X_train, y_train, validation_data=(X_val, y_val),
        epochs=epochs, batch_size=batch_size, shuffle=False)
        metrics = model.evaluate(X_test, y_test)
        hist_list.append(history)
        loss_list.append(metrics[2])
    
    plot_train_data(hist_list, approach='history')
    # plot_train_data(loss_list, approach='loss')
    return model, hist_list, loss_list

def forecast(model, df, timesteps, multisteps, scaler):
    input_seq = df[-timesteps:].values #getting the last sequence of known value
    inp = input_seq
    predictions = list()

    for step in range(1, multisteps+1):
        inp = inp.reshape(1, timesteps, 1)
        yhat = model.predict(inp)
        yhat_inversed = scaler.inverse_transform(yhat)
        predictions.append(yhat_inversed[0][0])
        #prepare new input to forecast the next day
        inp = np.append(inp[0], yhat)
        inp = inp[-timesteps:]
    return predictions

def plot_forecast(data, forecasts):
    plt.figure(figsize=(8,6))
    plt.plot(range(len(data)), data, color='green', label='Confirmed')
    plt.plot(range(len(data)-1, len(data)+len(forecasts)-1), forecasts, color='red', label='Forecasts')
    plt.title('Number of incidents')
    plt.ylabel('Incidents')
    plt.xlabel('Days')
    plt.legend()
    plt.show()

# %%
model = build_model(timesteps, univariate)

# %%
model, hist_list, loss_list = compile_and_fit(model, epochs, batch_size)
# plot_learning_curves(hist_list, epochs)
# Out:
# Epoch 1/50
# 161/161 [==============================] - 1s 4ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 2/50
# 161/161 [==============================] - 0s 2ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 3/50
# 161/161 [==============================] - 0s 2ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 4/50
# 161/161 [==============================] - 0s 2ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 5/50
# 161/161 [==============================] - 0s 2ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 6/50
# 161/161 [==============================] - 0s 2ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 7/50
# 161/161 [==============================] - 0s 2ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 8/50
# 161/161 [==============================] - 0s 3ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 9/50
# 161/161 [==============================] - 0s 2ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 10/50
# 161/161 [==============================] - 0s 2ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 11/50
# 161/161 [==============================] - 0s 2ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 12/50
# 161/161 [==============================] - 0s 2ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 13/50
# 161/161 [==============================] - 0s 2ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 14/50
# 161/161 [==============================] - 0s 2ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 15/50
# 161/161 [==============================] - 0s 2ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 16/50
# 161/161 [==============================] - 0s 2ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 17/50
# 161/161 [==============================] - 0s 2ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 18/50
# 161/161 [==============================] - 0s 2ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 19/50
# 161/161 [==============================] - 0s 2ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 20/50
# 161/161 [==============================] - 0s 2ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 21/50
# 161/161 [==============================] - 0s 2ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 22/50
# 161/161 [==============================] - 0s 2ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 23/50
# 161/161 [==============================] - 0s 2ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 24/50
# 161/161 [==============================] - 0s 2ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 25/50
# 161/161 [==============================] - 0s 2ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 26/50
# 161/161 [==============================] - 0s 2ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 27/50
# 161/161 [==============================] - 0s 2ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 28/50
# 161/161 [==============================] - 0s 2ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 29/50
# 161/161 [==============================] - 0s 2ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 30/50
# 161/161 [==============================] - 0s 2ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 31/50
# 161/161 [==============================] - 0s 2ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 32/50
# 161/161 [==============================] - 0s 2ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 33/50
# 161/161 [==============================] - 0s 2ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 34/50
# 161/161 [==============================] - 0s 3ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 35/50
# 161/161 [==============================] - 1s 4ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 36/50
# 161/161 [==============================] - 1s 3ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 37/50
# 161/161 [==============================] - 0s 2ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 38/50
# 161/161 [==============================] - 0s 2ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 39/50
# 161/161 [==============================] - 0s 3ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 40/50
# 161/161 [==============================] - 0s 3ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 41/50
# 161/161 [==============================] - 0s 3ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 42/50
# 161/161 [==============================] - 0s 2ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 43/50
# 161/161 [==============================] - 0s 2ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 44/50
# 161/161 [==============================] - 0s 2ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 45/50
# 161/161 [==============================] - 0s 1ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 46/50
# 161/161 [==============================] - 0s 3ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 47/50
# 161/161 [==============================] - 0s 3ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 48/50
# 161/161 [==============================] - 0s 2ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 49/50
# 161/161 [==============================] - 0s 3ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 50/50
# 161/161 [==============================] - 1s 4ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# 39/39 [==============================] - 0s 2ms/step - loss: nan - mae: nan - rmse: nan
# Epoch 1/50
# 322/322 [==============================] - 1s 2ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 2/50
# 322/322 [==============================] - 1s 2ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 3/50
# 322/322 [==============================] - 1s 2ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 4/50
# 322/322 [==============================] - 1s 2ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 5/50
# 322/322 [==============================] - 0s 1ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 6/50
# 322/322 [==============================] - 1s 2ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 7/50
# 322/322 [==============================] - 0s 1ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 8/50
# 322/322 [==============================] - 1s 2ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 9/50
# 322/322 [==============================] - 1s 2ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 10/50
# 322/322 [==============================] - 1s 2ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 11/50
# 322/322 [==============================] - 1s 2ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 12/50
# 322/322 [==============================] - 1s 2ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 13/50
# 322/322 [==============================] - 1s 3ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 14/50
# 322/322 [==============================] - 2s 6ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 15/50
# 322/322 [==============================] - 1s 4ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 16/50
# 322/322 [==============================] - 1s 3ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 17/50
# 322/322 [==============================] - 1s 3ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 18/50
# 322/322 [==============================] - 1s 3ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 19/50
# 322/322 [==============================] - 1s 3ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 20/50
# 322/322 [==============================] - 0s 2ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 21/50
# 322/322 [==============================] - 1s 2ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 22/50
# 322/322 [==============================] - 0s 1ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 23/50
# 322/322 [==============================] - 0s 2ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 24/50
# 322/322 [==============================] - 1s 2ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 25/50
# 322/322 [==============================] - 0s 2ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 26/50
# 322/322 [==============================] - 1s 2ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 27/50
# 322/322 [==============================] - 1s 2ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 28/50
# 322/322 [==============================] - 1s 2ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 29/50
# 322/322 [==============================] - 1s 2ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 30/50
# 322/322 [==============================] - 1s 2ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 31/50
# 322/322 [==============================] - 1s 2ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 32/50
# 322/322 [==============================] - 1s 2ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 33/50
# 322/322 [==============================] - 1s 3ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 34/50
# 322/322 [==============================] - 1s 3ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 35/50
# 322/322 [==============================] - 1s 4ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 36/50
# 322/322 [==============================] - 1s 3ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 37/50
# 322/322 [==============================] - 1s 3ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 38/50
# 322/322 [==============================] - 1s 3ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 39/50
# 322/322 [==============================] - 1s 2ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 40/50
# 322/322 [==============================] - 1s 4ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 41/50
# 322/322 [==============================] - 1s 3ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 42/50
# 322/322 [==============================] - 1s 3ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 43/50
# 322/322 [==============================] - 1s 3ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 44/50
# 322/322 [==============================] - 1s 3ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 45/50
# 322/322 [==============================] - 1s 3ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 46/50
# 322/322 [==============================] - 1s 3ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 47/50
# 322/322 [==============================] - 1s 3ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 48/50
# 322/322 [==============================] - 1s 2ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 49/50
# 322/322 [==============================] - 1s 2ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 50/50
# 322/322 [==============================] - 1s 3ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# 39/39 [==============================] - 0s 3ms/step - loss: nan - mae: nan - rmse: nan
# Epoch 1/50
# 482/482 [==============================] - 1s 2ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 2/50
# 482/482 [==============================] - 1s 2ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 3/50
# 482/482 [==============================] - 1s 2ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 4/50
# 482/482 [==============================] - 1s 2ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 5/50
# 482/482 [==============================] - 1s 3ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 6/50
# 482/482 [==============================] - 1s 2ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 7/50
# 482/482 [==============================] - 1s 2ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 8/50
# 482/482 [==============================] - 1s 3ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 9/50
# 482/482 [==============================] - 1s 3ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 10/50
# 482/482 [==============================] - 1s 3ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 11/50
# 482/482 [==============================] - 1s 3ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 12/50
# 482/482 [==============================] - 1s 3ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 13/50
# 482/482 [==============================] - 1s 3ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 14/50
# 482/482 [==============================] - 1s 3ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 15/50
# 482/482 [==============================] - 2s 3ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 16/50
# 482/482 [==============================] - 2s 3ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 17/50
# 482/482 [==============================] - 1s 2ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 18/50
# 482/482 [==============================] - 1s 3ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 19/50
# 482/482 [==============================] - 1s 3ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 20/50
# 482/482 [==============================] - 1s 3ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 21/50
# 482/482 [==============================] - 1s 2ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 22/50
# 482/482 [==============================] - 2s 4ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 23/50
# 482/482 [==============================] - 2s 5ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 24/50
# 482/482 [==============================] - 1s 3ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 25/50
# 482/482 [==============================] - 1s 2ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 26/50
# 482/482 [==============================] - 1s 2ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 27/50
# 482/482 [==============================] - 1s 2ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 28/50
# 482/482 [==============================] - 1s 2ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 29/50
# 482/482 [==============================] - 1s 2ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 30/50
# 482/482 [==============================] - 2s 3ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 31/50
# 482/482 [==============================] - 1s 3ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 32/50
# 482/482 [==============================] - 1s 2ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 33/50
# 482/482 [==============================] - 1s 2ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 34/50
# 482/482 [==============================] - 1s 2ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 35/50
# 482/482 [==============================] - 1s 3ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 36/50
# 482/482 [==============================] - 1s 2ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 37/50
# 482/482 [==============================] - 1s 2ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 38/50
# 482/482 [==============================] - 1s 2ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 39/50
# 482/482 [==============================] - 1s 2ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 40/50
# 482/482 [==============================] - 1s 2ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 41/50
# 482/482 [==============================] - 1s 2ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 42/50
# 482/482 [==============================] - 1s 2ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 43/50
# 482/482 [==============================] - 2s 3ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 44/50
# 482/482 [==============================] - 1s 2ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 45/50
# 482/482 [==============================] - 1s 2ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 46/50
# 482/482 [==============================] - 1s 2ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 47/50
# 482/482 [==============================] - 2s 3ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 48/50
# 482/482 [==============================] - 1s 3ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 49/50
# 482/482 [==============================] - 1s 2ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# Epoch 50/50
# 482/482 [==============================] - 1s 2ms/step - loss: nan - mae: nan - rmse: nan - val_loss: nan - val_mae: nan - val_rmse: nan
# 39/39 [==============================] - 0s 3ms/step - loss: nan - mae: nan - rmse: nan
# /tmp/ipykernel_63617/2098902511.py:49: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(3,1,i+1)

# %%
forecasts = forecast(model, bd, timesteps, multisteps, scaler)
# Out:
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step

# %%
print(forecasts)
# Out:
# [nan, nan, nan, nan, nan]

# %%
plot_forecast(bd, forecasts)
