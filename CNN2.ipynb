# %%
!%pip install tensorflow
!%pip install scikit-learn
!%pip install matplotlib
!%pip install pandas
!%pip install pydot

# %%
import tensorflow as tf
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import TimeSeriesSplit
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, SimpleRNN
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import importlib as imp
import datacleaner
import datetime
imp.reload(datacleaner)

from datacleaner import *

# %%
np.random.seed(1)
tf.keras.backend.clear_session()

bd = pd.read_csv(r"training_data.csv")

# %%
timesteps = 7 #number of days that make up a sequence
univariate = 1 #number of features used by the model (using incidents to predict incidents)
multisteps = 7 #number of days to forecast – we will forecast the next 7 days
cv_splits = 3 #time series cross validator
epochs = 50
batch_size = 7 #7 sequences of 7 days - which corresponds to a window of 7 days in a batch

# %%
bd.head()
# Out:
#    city_name magnitude_of_delay  delay_in_seconds
# 0  Guimaraes          UNDEFINED                 0  \
# 1  Guimaraes          UNDEFINED               385
# 2  Guimaraes          UNDEFINED                69
# 3  Guimaraes              MAJOR              2297
# 4  Guimaraes          UNDEFINED                 0
#
#                                       affected_roads       record_date
# 0                                                  ,  2021-03-15 23:00  \
# 1                                              N101,  2021-12-25 18:00
# 2                                                  ,  2021-03-12 15:00
# 3  N101,R206,N105,N101,N101,N101,N101,N101,N101,N...  2021-09-29 09:00
# 4                          N101,N101,N101,N101,N101,  2021-06-13 11:00
#
#   luminosity  avg_temperature  avg_atm_pressure  avg_humidity  avg_wind_speed
# 0       DARK             12.0            1013.0          70.0             1.0  \
# 1       DARK             12.0            1007.0          91.0             1.0
# 2      LIGHT             14.0            1025.0          64.0             0.0
# 3      LIGHT             15.0            1028.0          75.0             1.0
# 4      LIGHT             27.0            1020.0          52.0             1.0
#
#    avg_precipitation   avg_rain  incidents
# 0                0.0  Sem Chuva        NaN
# 1                0.0  Sem Chuva        NaN
# 2                0.0  Sem Chuva        Low
# 3                0.0  Sem Chuva  Very_High
# 4                0.0  Sem Chuva       High

# %%
def prepare_data(bd):
    bd = ordernar(bd)
    # bd = RoadsCleaner(bd)
    #bd = data(bd)
    # bd = valores_em_falta(bd)
    # bd = eliminar(bd)
    bd = incidentsNumbers(bd)
    # bd = luminosidade(bd)
    # bd = rainNumbers(bd)
    # bd = delayNumbers(bd)
    bd = removeOutlier(bd)
    bd.index = pd.to_datetime(bd["record_date"], format="%Y-%m-%d %H:%M:00")
    bd = bd[['incidents']]
    return bd

def data_normalization(bd, norm_range=(-1, 1)):
    scaler = MinMaxScaler(feature_range=norm_range)
    bd[['incidents']] = scaler.fit_transform(bd[['incidents']])
    return scaler

def to_supervised(df, timesteps):
    data = df.values
    X, y = list(), list()
    dataset_size = len(data)
    for curr_pos in range(dataset_size):
        input_index = curr_pos + timesteps
        label_index = input_index + 1

        if label_index < dataset_size:
            X.append(data[curr_pos:input_index,:])
            y.append(data[input_index:label_index, 0])
    
    return np.array(X).astype('float32'), np.array(y).astype('float32')

def split_data(bd, perc=10):
    train_idx = np.arange(0, int(len(bd)*(100-perc)/100))
    val_idx = np.arange(int(len(bd)*(100-perc)/100+1), len(bd))
    return train_idx, val_idx

# %%
bd = prepare_data(bd)
# Out:
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor
# /home/diogofrosario/Desktop/trabalho-CSC/datacleaner.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd["delay_in_seconds"][count] = valor

# %%
bd.head()
# Out:
#                      incidents
# record_date
# 2021-01-16 16:00:00        3.0
# 2021-01-16 18:00:00        2.0
# 2021-01-16 19:00:00        2.0
# 2021-01-16 20:00:00        2.0
# 2021-01-16 21:00:00        3.0

# %%
scaler = data_normalization(bd)
bd.head()
# Out:
#                      incidents
# record_date
# 2021-01-16 16:00:00   0.333333
# 2021-01-16 18:00:00  -0.333333
# 2021-01-16 19:00:00  -0.333333
# 2021-01-16 20:00:00  -0.333333
# 2021-01-16 21:00:00   0.333333

# %%
bd['incidents'] = bd['incidents'].resample("H").interpolate(method="time")
bd = bd[bd.index.month !=8]
print(bd)
fig=plt.figure()
plt.plot(bd)
spacing =10
fig.subplots_adjust(right=spacing)
plt.show()
# Out:
#                      incidents
# record_date
# 2021-01-16 16:00:00   0.333333
# 2021-01-16 18:00:00  -0.333333
# 2021-01-16 19:00:00  -0.333333
# 2021-01-16 20:00:00  -0.333333
# 2021-01-16 21:00:00   0.333333
# ...                        ...
# 2021-12-31 17:00:00  -0.333333
# 2021-12-31 18:00:00  -0.333333
# 2021-12-31 19:00:00  -0.333333
# 2021-12-31 20:00:00  -0.333333
# 2021-12-31 23:00:00  -0.333333
#
# [5000 rows x 1 columns]

# %%
X, y = to_supervised(bd, timesteps)
X.shape, y.shape
# Out:
# ((4992, 7, 1), (4992, 1))

# %%
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.optimizers import Adam

# %%
def rmse(y_true, y_pred):
    return tf.keras.backend.sqrt(tf.keras.backend.mean(tf.keras.backend.square(y_pred - y_true)))

def build_model(timesteps, features, filters=16, kernel_size=5, pool_size=2):
    #using the Functional API
    inputs = tf.keras.layers.Input(shape=(timesteps, features))
    print(inputs)
    #microarchitecture
    x = tf.keras.layers.Conv1D(filters=filters, kernel_size=kernel_size,
    activation='relu', data_format='channels_last')(inputs)
    x = tf.keras.layers.AveragePooling1D(pool_size=pool_size,
    data_format='channels_first')(x)
    #last layers
    x = tf.keras.layers.Flatten()(x)
    x = tf.keras.layers.Dense(filters)(x)
    outputs = tf.keras.layers.Dense(1)(x)
    #the model
    cnnModel = tf.keras.Model(inputs=inputs, outputs=outputs, name='cnn_model')
    tf.keras.utils.plot_model(cnnModel, 'cnn.png', show_shapes=True)
    return cnnModel

def plot_learning_curves(history, epochs):
    #accuracies and losses
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    epochs_range = range(epochs)
    #creating figure
    plt.figure(figsize=(8, 8))
    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, acc, label='Training Accuracy')
    plt.plot(epochs_range, val_acc, label='Validation Accuracy')
    plt.legend(loc='lower right')
    plt.title('Training/Validation Accuracy')
    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, loss, label='Training Loss')
    plt.plot(epochs_range, val_loss, label='Validation Loss')
    plt.legend(loc='upper right')
    plt.title('Training/Validation Loss')
    plt.show()

def plot_train_data(data, approach='history'):
    plt.figure(figsize=(8,6))
    if approach == 'history':
        plt.title('Model train vs val loss per Training Split')
        plt.ylabel('Training RMSE (Normalized)')
        plt.xlabel('Epoch')
        for hist, i in zip(data, range(len(data))):  
            plt.subplot(3,1,i+1)      
            plt.plot(hist.epoch, hist.history['loss'])
            plt.plot(hist.epoch, hist.history['val_loss'])
            plt.xlim([0, max(hist.epoch)])  
            plt.legend(['Training split ' + str(i+1) + ' - train loss', 'Training split ' + str(i+1) + ' - val loss'], loc='upper right')
        plt.show()   
    elif approach == 'loss':
        plt.figure(figsize=(6,3))
        plt.plot(range(len(data)), data)
        plt.title('RMSE value per Timeseries split')
        plt.ylabel('Evaluation RMSE')
        plt.xlabel('Timeseries Splits')
        plt.xlim([0, 2])
        plt.ylim([0, (np.amax(data)+2)])
        plt.show()

def compile_and_fit(model, epochs, batch_size):
    #compile
    model.compile(loss = rmse, optimizer = tf.keras.optimizers.Adam(), metrics = ['mae', rmse])
    #fit
    hist_list = list()
    loss_list = list()
    #Time Series Cross Validator
    tscv = TimeSeriesSplit(n_splits=cv_splits)
    for train_index, test_index in tscv.split(X):
        train_idx, val_idx = split_data(train_index, perc=10) #further split into training and validation sets
        #build data
        X_train, y_train = X[train_idx], y[train_idx]
        X_val, y_val = X[val_idx], y[val_idx]
        X_test, y_test = X[test_index], y[test_index]
        history = model.fit(X_train, y_train, validation_data=(X_val, y_val),
        epochs=epochs, batch_size=batch_size, shuffle=False)
        metrics = model.evaluate(X_test, y_test)
        hist_list.append(history)
        loss_list.append(metrics[2])
    plot_train_data(hist_list, approach='history')
    # plot_learning_curves(loss_list, approach='loss')
    return model, hist_list, loss_list

def forecast(model, df, timesteps, multisteps, scaler):
    input_seq = df[-timesteps:].values #getting the last sequence of known value
    inp = input_seq
    predictions = list()
    for _ in range(1, multisteps+1):
        inp = inp.reshape(1, timesteps, 1)
        yhat = model.predict(inp)
        yhat_inversed = scaler.inverse_transform(yhat)
        predictions.append(yhat_inversed[0][0])
        #prepare new input to forecast the next day
        inp = np.append(inp[0], yhat)
        inp = inp[-timesteps:]
    return predictions

def plot_forecast(data, forecasts):
    plt.figure(figsize=(8,6))
    plt.plot(range(len(data)), data, color='green', label='Confirmed')
    plt.plot(range(len(data)-1, len(data)+len(forecasts)-1), forecasts, color='red', label='Forecasts')
    plt.title('Number of incidents')
    plt.ylabel('Incidents')
    plt.xlabel('Days')
    plt.legend()
    plt.show()

# %%
model = build_model(timesteps, univariate)
# Out:
# KerasTensor(type_spec=TensorSpec(shape=(None, 7, 1), dtype=tf.float32, name='input_2'), name='input_2', description="created by layer 'input_2'")

# %%
model, hist_list, loss_list = compile_and_fit(model, epochs, batch_size)
# Out:
# Epoch 1/50
# 161/161 [==============================] - 1s 3ms/step - loss: 0.4003 - mae: 0.3460 - rmse: 0.4000 - val_loss: 0.3144 - val_mae: 0.2741 - val_rmse: 0.3129
# Epoch 2/50
# 161/161 [==============================] - 0s 1ms/step - loss: 0.3018 - mae: 0.2491 - rmse: 0.3013 - val_loss: 0.2690 - val_mae: 0.2252 - val_rmse: 0.2679
# Epoch 3/50
# 161/161 [==============================] - 0s 3ms/step - loss: 0.2858 - mae: 0.2356 - rmse: 0.2852 - val_loss: 0.2620 - val_mae: 0.2095 - val_rmse: 0.2615
# Epoch 4/50
# 161/161 [==============================] - 1s 4ms/step - loss: 0.2583 - mae: 0.2049 - rmse: 0.2579 - val_loss: 0.2752 - val_mae: 0.2156 - val_rmse: 0.2753
# Epoch 5/50
# 161/161 [==============================] - 1s 4ms/step - loss: 0.2621 - mae: 0.2100 - rmse: 0.2617 - val_loss: 0.2777 - val_mae: 0.2141 - val_rmse: 0.2779
# Epoch 6/50
# 161/161 [==============================] - 0s 3ms/step - loss: 0.2476 - mae: 0.1929 - rmse: 0.2473 - val_loss: 0.2771 - val_mae: 0.2125 - val_rmse: 0.2774
# Epoch 7/50
# 161/161 [==============================] - 0s 3ms/step - loss: 0.2424 - mae: 0.1869 - rmse: 0.2421 - val_loss: 0.2775 - val_mae: 0.2125 - val_rmse: 0.2779
# Epoch 8/50
# 161/161 [==============================] - 0s 2ms/step - loss: 0.2434 - mae: 0.1878 - rmse: 0.2430 - val_loss: 0.2685 - val_mae: 0.2060 - val_rmse: 0.2690
# Epoch 9/50
# 161/161 [==============================] - 0s 2ms/step - loss: 0.2551 - mae: 0.2013 - rmse: 0.2547 - val_loss: 0.2682 - val_mae: 0.2054 - val_rmse: 0.2687
# Epoch 10/50
# 161/161 [==============================] - 0s 2ms/step - loss: 0.2509 - mae: 0.1961 - rmse: 0.2505 - val_loss: 0.2718 - val_mae: 0.2080 - val_rmse: 0.2724
# Epoch 11/50
# 161/161 [==============================] - 0s 1ms/step - loss: 0.2400 - mae: 0.1823 - rmse: 0.2396 - val_loss: 0.2679 - val_mae: 0.2037 - val_rmse: 0.2684
# Epoch 12/50
# 161/161 [==============================] - 0s 1ms/step - loss: 0.2335 - mae: 0.1736 - rmse: 0.2332 - val_loss: 0.2726 - val_mae: 0.2088 - val_rmse: 0.2732
# Epoch 13/50
# 161/161 [==============================] - 0s 1ms/step - loss: 0.2357 - mae: 0.1788 - rmse: 0.2354 - val_loss: 0.2853 - val_mae: 0.2259 - val_rmse: 0.2859
# Epoch 14/50
# 161/161 [==============================] - 0s 1ms/step - loss: 0.2305 - mae: 0.1727 - rmse: 0.2302 - val_loss: 0.2768 - val_mae: 0.2164 - val_rmse: 0.2773
# Epoch 15/50
# 161/161 [==============================] - 0s 1ms/step - loss: 0.2291 - mae: 0.1705 - rmse: 0.2287 - val_loss: 0.2660 - val_mae: 0.2038 - val_rmse: 0.2663
# Epoch 16/50
# 161/161 [==============================] - 0s 1ms/step - loss: 0.2310 - mae: 0.1725 - rmse: 0.2307 - val_loss: 0.2682 - val_mae: 0.2079 - val_rmse: 0.2686
# Epoch 17/50
# 161/161 [==============================] - 0s 2ms/step - loss: 0.2312 - mae: 0.1730 - rmse: 0.2308 - val_loss: 0.2664 - val_mae: 0.2056 - val_rmse: 0.2666
# Epoch 18/50
# 161/161 [==============================] - 0s 2ms/step - loss: 0.2309 - mae: 0.1728 - rmse: 0.2305 - val_loss: 0.2679 - val_mae: 0.2082 - val_rmse: 0.2683
# Epoch 19/50
# 161/161 [==============================] - 0s 2ms/step - loss: 0.2344 - mae: 0.1768 - rmse: 0.2340 - val_loss: 0.2682 - val_mae: 0.2060 - val_rmse: 0.2685
# Epoch 20/50
# 161/161 [==============================] - 0s 2ms/step - loss: 0.2276 - mae: 0.1681 - rmse: 0.2274 - val_loss: 0.2769 - val_mae: 0.2189 - val_rmse: 0.2774
# Epoch 21/50
# 161/161 [==============================] - 0s 2ms/step - loss: 0.2286 - mae: 0.1702 - rmse: 0.2282 - val_loss: 0.2660 - val_mae: 0.2069 - val_rmse: 0.2663
# Epoch 22/50
# 161/161 [==============================] - 0s 2ms/step - loss: 0.2281 - mae: 0.1692 - rmse: 0.2277 - val_loss: 0.2666 - val_mae: 0.2072 - val_rmse: 0.2669
# Epoch 23/50
# 161/161 [==============================] - 0s 2ms/step - loss: 0.2278 - mae: 0.1689 - rmse: 0.2274 - val_loss: 0.2664 - val_mae: 0.2074 - val_rmse: 0.2666
# Epoch 24/50
# 161/161 [==============================] - 0s 2ms/step - loss: 0.2286 - mae: 0.1703 - rmse: 0.2282 - val_loss: 0.2652 - val_mae: 0.2060 - val_rmse: 0.2654
# Epoch 25/50
# 161/161 [==============================] - 0s 3ms/step - loss: 0.2283 - mae: 0.1701 - rmse: 0.2279 - val_loss: 0.2656 - val_mae: 0.2068 - val_rmse: 0.2658
# Epoch 26/50
# 161/161 [==============================] - 0s 2ms/step - loss: 0.2281 - mae: 0.1698 - rmse: 0.2277 - val_loss: 0.2656 - val_mae: 0.2067 - val_rmse: 0.2658
# Epoch 27/50
# 161/161 [==============================] - 1s 3ms/step - loss: 0.2280 - mae: 0.1698 - rmse: 0.2276 - val_loss: 0.2657 - val_mae: 0.2073 - val_rmse: 0.2659
# Epoch 28/50
# 161/161 [==============================] - 0s 2ms/step - loss: 0.2280 - mae: 0.1694 - rmse: 0.2276 - val_loss: 0.2662 - val_mae: 0.2080 - val_rmse: 0.2664
# Epoch 29/50
# 161/161 [==============================] - 0s 2ms/step - loss: 0.2318 - mae: 0.1744 - rmse: 0.2314 - val_loss: 0.2667 - val_mae: 0.2065 - val_rmse: 0.2669
# Epoch 30/50
# 161/161 [==============================] - 0s 3ms/step - loss: 0.2282 - mae: 0.1688 - rmse: 0.2278 - val_loss: 0.2709 - val_mae: 0.2131 - val_rmse: 0.2713
# Epoch 31/50
# 161/161 [==============================] - 1s 3ms/step - loss: 0.2288 - mae: 0.1692 - rmse: 0.2286 - val_loss: 0.2782 - val_mae: 0.2231 - val_rmse: 0.2786
# Epoch 32/50
# 161/161 [==============================] - 1s 4ms/step - loss: 0.2281 - mae: 0.1694 - rmse: 0.2278 - val_loss: 0.2738 - val_mae: 0.2178 - val_rmse: 0.2741
# Epoch 33/50
# 161/161 [==============================] - 0s 2ms/step - loss: 0.2269 - mae: 0.1681 - rmse: 0.2266 - val_loss: 0.2698 - val_mae: 0.2116 - val_rmse: 0.2699
# Epoch 34/50
# 161/161 [==============================] - 0s 1ms/step - loss: 0.2277 - mae: 0.1696 - rmse: 0.2272 - val_loss: 0.2625 - val_mae: 0.2012 - val_rmse: 0.2625
# Epoch 35/50
# 161/161 [==============================] - 0s 1ms/step - loss: 0.2242 - mae: 0.1638 - rmse: 0.2239 - val_loss: 0.2735 - val_mae: 0.2158 - val_rmse: 0.2738
# Epoch 36/50
# 161/161 [==============================] - 0s 1ms/step - loss: 0.2261 - mae: 0.1665 - rmse: 0.2257 - val_loss: 0.2684 - val_mae: 0.2089 - val_rmse: 0.2686
# Epoch 37/50
# 161/161 [==============================] - 0s 1ms/step - loss: 0.2278 - mae: 0.1691 - rmse: 0.2274 - val_loss: 0.2649 - val_mae: 0.2058 - val_rmse: 0.2650
# Epoch 38/50
# 161/161 [==============================] - 0s 1ms/step - loss: 0.2261 - mae: 0.1658 - rmse: 0.2257 - val_loss: 0.2635 - val_mae: 0.2030 - val_rmse: 0.2636
# Epoch 39/50
# 161/161 [==============================] - 0s 1ms/step - loss: 0.2250 - mae: 0.1650 - rmse: 0.2247 - val_loss: 0.2696 - val_mae: 0.2101 - val_rmse: 0.2698
# Epoch 40/50
# 161/161 [==============================] - 0s 1ms/step - loss: 0.2251 - mae: 0.1652 - rmse: 0.2248 - val_loss: 0.2697 - val_mae: 0.2137 - val_rmse: 0.2700
# Epoch 41/50
# 161/161 [==============================] - 0s 1ms/step - loss: 0.2284 - mae: 0.1695 - rmse: 0.2280 - val_loss: 0.2625 - val_mae: 0.2016 - val_rmse: 0.2625
# Epoch 42/50
# 161/161 [==============================] - 0s 1ms/step - loss: 0.2226 - mae: 0.1620 - rmse: 0.2223 - val_loss: 0.2695 - val_mae: 0.2141 - val_rmse: 0.2697
# Epoch 43/50
# 161/161 [==============================] - 0s 1ms/step - loss: 0.2243 - mae: 0.1647 - rmse: 0.2240 - val_loss: 0.2636 - val_mae: 0.2051 - val_rmse: 0.2637
# Epoch 44/50
# 161/161 [==============================] - 0s 1ms/step - loss: 0.2251 - mae: 0.1654 - rmse: 0.2247 - val_loss: 0.2645 - val_mae: 0.2059 - val_rmse: 0.2646
# Epoch 45/50
# 161/161 [==============================] - 0s 1ms/step - loss: 0.2264 - mae: 0.1669 - rmse: 0.2261 - val_loss: 0.2674 - val_mae: 0.2122 - val_rmse: 0.2675
# Epoch 46/50
# 161/161 [==============================] - 0s 1ms/step - loss: 0.2297 - mae: 0.1712 - rmse: 0.2293 - val_loss: 0.2612 - val_mae: 0.2009 - val_rmse: 0.2612
# Epoch 47/50
# 161/161 [==============================] - 0s 1ms/step - loss: 0.2233 - mae: 0.1627 - rmse: 0.2230 - val_loss: 0.2674 - val_mae: 0.2103 - val_rmse: 0.2675
# Epoch 48/50
# 161/161 [==============================] - 0s 1ms/step - loss: 0.2220 - mae: 0.1623 - rmse: 0.2217 - val_loss: 0.2668 - val_mae: 0.2127 - val_rmse: 0.2669
# Epoch 49/50
# 161/161 [==============================] - 0s 1ms/step - loss: 0.2268 - mae: 0.1678 - rmse: 0.2264 - val_loss: 0.2618 - val_mae: 0.2044 - val_rmse: 0.2617
# Epoch 50/50
# 161/161 [==============================] - 0s 2ms/step - loss: 0.2228 - mae: 0.1631 - rmse: 0.2225 - val_loss: 0.2635 - val_mae: 0.2075 - val_rmse: 0.2635
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3124 - mae: 0.2405 - rmse: 0.3124
# Epoch 1/50
# 321/321 [==============================] - 1s 2ms/step - loss: 0.2389 - mae: 0.1787 - rmse: 0.2388 - val_loss: 0.3240 - val_mae: 0.2407 - val_rmse: 0.3213
# Epoch 2/50
# 321/321 [==============================] - 0s 1ms/step - loss: 0.2380 - mae: 0.1770 - rmse: 0.2379 - val_loss: 0.3260 - val_mae: 0.2377 - val_rmse: 0.3235
# Epoch 3/50
# 321/321 [==============================] - 0s 1ms/step - loss: 0.2398 - mae: 0.1793 - rmse: 0.2397 - val_loss: 0.3329 - val_mae: 0.2454 - val_rmse: 0.3303
# Epoch 4/50
# 321/321 [==============================] - 0s 2ms/step - loss: 0.2372 - mae: 0.1774 - rmse: 0.2371 - val_loss: 0.3229 - val_mae: 0.2351 - val_rmse: 0.3204
# Epoch 5/50
# 321/321 [==============================] - 0s 1ms/step - loss: 0.2368 - mae: 0.1768 - rmse: 0.2367 - val_loss: 0.3211 - val_mae: 0.2333 - val_rmse: 0.3186
# Epoch 6/50
# 321/321 [==============================] - 0s 1ms/step - loss: 0.2370 - mae: 0.1771 - rmse: 0.2369 - val_loss: 0.3221 - val_mae: 0.2344 - val_rmse: 0.3196
# Epoch 7/50
# 321/321 [==============================] - 0s 1ms/step - loss: 0.2369 - mae: 0.1770 - rmse: 0.2368 - val_loss: 0.3212 - val_mae: 0.2336 - val_rmse: 0.3188
# Epoch 8/50
# 321/321 [==============================] - 0s 1ms/step - loss: 0.2358 - mae: 0.1742 - rmse: 0.2357 - val_loss: 0.3303 - val_mae: 0.2427 - val_rmse: 0.3278
# Epoch 9/50
# 321/321 [==============================] - 0s 1ms/step - loss: 0.2408 - mae: 0.1808 - rmse: 0.2407 - val_loss: 0.3296 - val_mae: 0.2424 - val_rmse: 0.3270
# Epoch 10/50
# 321/321 [==============================] - 0s 1ms/step - loss: 0.2405 - mae: 0.1806 - rmse: 0.2404 - val_loss: 0.3302 - val_mae: 0.2433 - val_rmse: 0.3277
# Epoch 11/50
# 321/321 [==============================] - 0s 1ms/step - loss: 0.2367 - mae: 0.1760 - rmse: 0.2366 - val_loss: 0.3273 - val_mae: 0.2406 - val_rmse: 0.3250
# Epoch 12/50
# 321/321 [==============================] - 0s 1ms/step - loss: 0.2391 - mae: 0.1786 - rmse: 0.2390 - val_loss: 0.3226 - val_mae: 0.2400 - val_rmse: 0.3206
# Epoch 13/50
# 321/321 [==============================] - 0s 1ms/step - loss: 0.2357 - mae: 0.1749 - rmse: 0.2357 - val_loss: 0.3314 - val_mae: 0.2448 - val_rmse: 0.3289
# Epoch 14/50
# 321/321 [==============================] - 0s 1ms/step - loss: 0.2382 - mae: 0.1790 - rmse: 0.2381 - val_loss: 0.3211 - val_mae: 0.2346 - val_rmse: 0.3186
# Epoch 15/50
# 321/321 [==============================] - 0s 1ms/step - loss: 0.2361 - mae: 0.1762 - rmse: 0.2360 - val_loss: 0.3213 - val_mae: 0.2338 - val_rmse: 0.3188
# Epoch 16/50
# 321/321 [==============================] - 0s 1ms/step - loss: 0.2378 - mae: 0.1779 - rmse: 0.2377 - val_loss: 0.3220 - val_mae: 0.2377 - val_rmse: 0.3195
# Epoch 17/50
# 321/321 [==============================] - 0s 1ms/step - loss: 0.2386 - mae: 0.1784 - rmse: 0.2385 - val_loss: 0.3296 - val_mae: 0.2429 - val_rmse: 0.3271
# Epoch 18/50
# 321/321 [==============================] - 1s 2ms/step - loss: 0.2347 - mae: 0.1740 - rmse: 0.2347 - val_loss: 0.3252 - val_mae: 0.2380 - val_rmse: 0.3228
# Epoch 19/50
# 321/321 [==============================] - 0s 1ms/step - loss: 0.2381 - mae: 0.1786 - rmse: 0.2380 - val_loss: 0.3215 - val_mae: 0.2366 - val_rmse: 0.3190
# Epoch 20/50
# 321/321 [==============================] - 0s 1ms/step - loss: 0.2384 - mae: 0.1779 - rmse: 0.2383 - val_loss: 0.3298 - val_mae: 0.2434 - val_rmse: 0.3273
# Epoch 21/50
# 321/321 [==============================] - 0s 1ms/step - loss: 0.2358 - mae: 0.1750 - rmse: 0.2357 - val_loss: 0.3252 - val_mae: 0.2389 - val_rmse: 0.3228
# Epoch 22/50
# 321/321 [==============================] - 0s 1ms/step - loss: 0.2366 - mae: 0.1759 - rmse: 0.2365 - val_loss: 0.3266 - val_mae: 0.2401 - val_rmse: 0.3243
# Epoch 23/50
# 321/321 [==============================] - 0s 1ms/step - loss: 0.2365 - mae: 0.1768 - rmse: 0.2364 - val_loss: 0.3208 - val_mae: 0.2336 - val_rmse: 0.3183
# Epoch 24/50
# 321/321 [==============================] - 0s 1ms/step - loss: 0.2383 - mae: 0.1787 - rmse: 0.2382 - val_loss: 0.3230 - val_mae: 0.2408 - val_rmse: 0.3205
# Epoch 25/50
# 321/321 [==============================] - 0s 1ms/step - loss: 0.2376 - mae: 0.1775 - rmse: 0.2375 - val_loss: 0.3229 - val_mae: 0.2406 - val_rmse: 0.3204
# Epoch 26/50
# 321/321 [==============================] - 0s 1ms/step - loss: 0.2346 - mae: 0.1739 - rmse: 0.2345 - val_loss: 0.3216 - val_mae: 0.2369 - val_rmse: 0.3191
# Epoch 27/50
# 321/321 [==============================] - 0s 1ms/step - loss: 0.2343 - mae: 0.1735 - rmse: 0.2342 - val_loss: 0.3221 - val_mae: 0.2385 - val_rmse: 0.3196
# Epoch 28/50
# 321/321 [==============================] - 0s 1ms/step - loss: 0.2358 - mae: 0.1747 - rmse: 0.2357 - val_loss: 0.3285 - val_mae: 0.2417 - val_rmse: 0.3260
# Epoch 29/50
# 321/321 [==============================] - 0s 1ms/step - loss: 0.2377 - mae: 0.1773 - rmse: 0.2376 - val_loss: 0.3332 - val_mae: 0.2478 - val_rmse: 0.3307
# Epoch 30/50
# 321/321 [==============================] - 1s 2ms/step - loss: 0.2381 - mae: 0.1786 - rmse: 0.2380 - val_loss: 0.3223 - val_mae: 0.2397 - val_rmse: 0.3198
# Epoch 31/50
# 321/321 [==============================] - 0s 1ms/step - loss: 0.2369 - mae: 0.1767 - rmse: 0.2368 - val_loss: 0.3221 - val_mae: 0.2387 - val_rmse: 0.3196
# Epoch 32/50
# 321/321 [==============================] - 0s 1ms/step - loss: 0.2378 - mae: 0.1773 - rmse: 0.2378 - val_loss: 0.3257 - val_mae: 0.2391 - val_rmse: 0.3232
# Epoch 33/50
# 321/321 [==============================] - 0s 1ms/step - loss: 0.2355 - mae: 0.1747 - rmse: 0.2354 - val_loss: 0.3309 - val_mae: 0.2446 - val_rmse: 0.3284
# Epoch 34/50
# 321/321 [==============================] - 0s 1ms/step - loss: 0.2357 - mae: 0.1752 - rmse: 0.2356 - val_loss: 0.3279 - val_mae: 0.2414 - val_rmse: 0.3255
# Epoch 35/50
# 321/321 [==============================] - 0s 1ms/step - loss: 0.2367 - mae: 0.1767 - rmse: 0.2366 - val_loss: 0.3220 - val_mae: 0.2396 - val_rmse: 0.3195
# Epoch 36/50
# 321/321 [==============================] - 0s 1ms/step - loss: 0.2334 - mae: 0.1715 - rmse: 0.2333 - val_loss: 0.3290 - val_mae: 0.2425 - val_rmse: 0.3265
# Epoch 37/50
# 321/321 [==============================] - 0s 1ms/step - loss: 0.2345 - mae: 0.1735 - rmse: 0.2344 - val_loss: 0.3257 - val_mae: 0.2396 - val_rmse: 0.3233
# Epoch 38/50
# 321/321 [==============================] - 0s 1ms/step - loss: 0.2334 - mae: 0.1720 - rmse: 0.2333 - val_loss: 0.3250 - val_mae: 0.2385 - val_rmse: 0.3226
# Epoch 39/50
# 321/321 [==============================] - 0s 1ms/step - loss: 0.2344 - mae: 0.1743 - rmse: 0.2343 - val_loss: 0.3223 - val_mae: 0.2355 - val_rmse: 0.3199
# Epoch 40/50
# 321/321 [==============================] - 0s 1ms/step - loss: 0.2339 - mae: 0.1722 - rmse: 0.2338 - val_loss: 0.3315 - val_mae: 0.2457 - val_rmse: 0.3289
# Epoch 41/50
# 321/321 [==============================] - 0s 1ms/step - loss: 0.2383 - mae: 0.1787 - rmse: 0.2383 - val_loss: 0.3215 - val_mae: 0.2374 - val_rmse: 0.3191
# Epoch 42/50
# 321/321 [==============================] - 0s 1ms/step - loss: 0.2368 - mae: 0.1766 - rmse: 0.2367 - val_loss: 0.3240 - val_mae: 0.2442 - val_rmse: 0.3215
# Epoch 43/50
# 321/321 [==============================] - 0s 1ms/step - loss: 0.2387 - mae: 0.1787 - rmse: 0.2387 - val_loss: 0.3211 - val_mae: 0.2350 - val_rmse: 0.3187
# Epoch 44/50
# 321/321 [==============================] - 1s 2ms/step - loss: 0.2342 - mae: 0.1738 - rmse: 0.2341 - val_loss: 0.3214 - val_mae: 0.2382 - val_rmse: 0.3190
# Epoch 45/50
# 321/321 [==============================] - 0s 1ms/step - loss: 0.2353 - mae: 0.1735 - rmse: 0.2352 - val_loss: 0.3210 - val_mae: 0.2343 - val_rmse: 0.3185
# Epoch 46/50
# 321/321 [==============================] - 0s 1ms/step - loss: 0.2355 - mae: 0.1748 - rmse: 0.2355 - val_loss: 0.3280 - val_mae: 0.2416 - val_rmse: 0.3255
# Epoch 47/50
# 321/321 [==============================] - 0s 1ms/step - loss: 0.2328 - mae: 0.1713 - rmse: 0.2327 - val_loss: 0.3246 - val_mae: 0.2375 - val_rmse: 0.3221
# Epoch 48/50
# 321/321 [==============================] - 0s 1ms/step - loss: 0.2327 - mae: 0.1709 - rmse: 0.2327 - val_loss: 0.3253 - val_mae: 0.2382 - val_rmse: 0.3228
# Epoch 49/50
# 321/321 [==============================] - 0s 1ms/step - loss: 0.2332 - mae: 0.1715 - rmse: 0.2332 - val_loss: 0.3284 - val_mae: 0.2416 - val_rmse: 0.3259
# Epoch 50/50
# 321/321 [==============================] - 0s 1ms/step - loss: 0.2327 - mae: 0.1710 - rmse: 0.2326 - val_loss: 0.3251 - val_mae: 0.2380 - val_rmse: 0.3226
# 39/39 [==============================] - 0s 1ms/step - loss: 0.4335 - mae: 0.2566 - rmse: 0.4335
# Epoch 1/50
# 482/482 [==============================] - 1s 1ms/step - loss: 0.2619 - mae: 0.1917 - rmse: 0.2640 - val_loss: 0.4503 - val_mae: 0.3619 - val_rmse: 0.4555
# Epoch 2/50
# 482/482 [==============================] - 1s 1ms/step - loss: 0.2639 - mae: 0.1943 - rmse: 0.2659 - val_loss: 0.4471 - val_mae: 0.3582 - val_rmse: 0.4523
# Epoch 3/50
# 482/482 [==============================] - 1s 1ms/step - loss: 0.2616 - mae: 0.1906 - rmse: 0.2637 - val_loss: 0.4307 - val_mae: 0.3390 - val_rmse: 0.4359
# Epoch 4/50
# 482/482 [==============================] - 1s 2ms/step - loss: 0.2647 - mae: 0.1960 - rmse: 0.2668 - val_loss: 0.4279 - val_mae: 0.3363 - val_rmse: 0.4330
# Epoch 5/50
# 482/482 [==============================] - 1s 1ms/step - loss: 0.2634 - mae: 0.1939 - rmse: 0.2654 - val_loss: 0.4165 - val_mae: 0.3260 - val_rmse: 0.4215
# Epoch 6/50
# 482/482 [==============================] - 1s 1ms/step - loss: 0.2625 - mae: 0.1929 - rmse: 0.2645 - val_loss: 0.4472 - val_mae: 0.3575 - val_rmse: 0.4525
# Epoch 7/50
# 482/482 [==============================] - 1s 1ms/step - loss: 0.2620 - mae: 0.1924 - rmse: 0.2640 - val_loss: 0.4458 - val_mae: 0.3561 - val_rmse: 0.4510
# Epoch 8/50
# 482/482 [==============================] - 1s 1ms/step - loss: 0.2627 - mae: 0.1922 - rmse: 0.2647 - val_loss: 0.4459 - val_mae: 0.3557 - val_rmse: 0.4511
# Epoch 9/50
# 482/482 [==============================] - 1s 1ms/step - loss: 0.2637 - mae: 0.1934 - rmse: 0.2657 - val_loss: 0.4399 - val_mae: 0.3488 - val_rmse: 0.4451
# Epoch 10/50
# 482/482 [==============================] - 1s 1ms/step - loss: 0.2634 - mae: 0.1928 - rmse: 0.2654 - val_loss: 0.4150 - val_mae: 0.3238 - val_rmse: 0.4200
# Epoch 11/50
# 482/482 [==============================] - 1s 1ms/step - loss: 0.2592 - mae: 0.1881 - rmse: 0.2612 - val_loss: 0.4251 - val_mae: 0.3317 - val_rmse: 0.4303
# Epoch 12/50
# 482/482 [==============================] - 1s 1ms/step - loss: 0.2586 - mae: 0.1875 - rmse: 0.2606 - val_loss: 0.4255 - val_mae: 0.3320 - val_rmse: 0.4307
# Epoch 13/50
# 482/482 [==============================] - 1s 2ms/step - loss: 0.2621 - mae: 0.1918 - rmse: 0.2641 - val_loss: 0.4249 - val_mae: 0.3313 - val_rmse: 0.4301
# Epoch 14/50
# 482/482 [==============================] - 1s 1ms/step - loss: 0.2620 - mae: 0.1921 - rmse: 0.2640 - val_loss: 0.4138 - val_mae: 0.3210 - val_rmse: 0.4188
# Epoch 15/50
# 482/482 [==============================] - 1s 1ms/step - loss: 0.2579 - mae: 0.1867 - rmse: 0.2599 - val_loss: 0.4263 - val_mae: 0.3325 - val_rmse: 0.4315
# Epoch 16/50
# 482/482 [==============================] - 1s 1ms/step - loss: 0.2576 - mae: 0.1858 - rmse: 0.2596 - val_loss: 0.4128 - val_mae: 0.3196 - val_rmse: 0.4179
# Epoch 17/50
# 482/482 [==============================] - 1s 1ms/step - loss: 0.2611 - mae: 0.1906 - rmse: 0.2631 - val_loss: 0.4382 - val_mae: 0.3457 - val_rmse: 0.4434
# Epoch 18/50
# 482/482 [==============================] - 1s 1ms/step - loss: 0.2594 - mae: 0.1880 - rmse: 0.2614 - val_loss: 0.4246 - val_mae: 0.3302 - val_rmse: 0.4298
# Epoch 19/50
# 482/482 [==============================] - 1s 1ms/step - loss: 0.2586 - mae: 0.1871 - rmse: 0.2606 - val_loss: 0.4393 - val_mae: 0.3467 - val_rmse: 0.4445
# Epoch 20/50
# 482/482 [==============================] - 1s 2ms/step - loss: 0.2605 - mae: 0.1890 - rmse: 0.2625 - val_loss: 0.4216 - val_mae: 0.3265 - val_rmse: 0.4267
# Epoch 21/50
# 482/482 [==============================] - 1s 1ms/step - loss: 0.2577 - mae: 0.1860 - rmse: 0.2596 - val_loss: 0.4215 - val_mae: 0.3263 - val_rmse: 0.4267
# Epoch 22/50
# 482/482 [==============================] - 1s 1ms/step - loss: 0.2577 - mae: 0.1864 - rmse: 0.2597 - val_loss: 0.4383 - val_mae: 0.3450 - val_rmse: 0.4435
# Epoch 23/50
# 482/482 [==============================] - 1s 1ms/step - loss: 0.2630 - mae: 0.1930 - rmse: 0.2650 - val_loss: 0.4249 - val_mae: 0.3298 - val_rmse: 0.4300
# Epoch 24/50
# 482/482 [==============================] - 1s 1ms/step - loss: 0.2576 - mae: 0.1867 - rmse: 0.2596 - val_loss: 0.4242 - val_mae: 0.3288 - val_rmse: 0.4293
# Epoch 25/50
# 482/482 [==============================] - 1s 1ms/step - loss: 0.2613 - mae: 0.1908 - rmse: 0.2632 - val_loss: 0.4244 - val_mae: 0.3289 - val_rmse: 0.4295
# Epoch 26/50
# 482/482 [==============================] - 1s 1ms/step - loss: 0.2599 - mae: 0.1893 - rmse: 0.2619 - val_loss: 0.4204 - val_mae: 0.3244 - val_rmse: 0.4255
# Epoch 27/50
# 482/482 [==============================] - 1s 2ms/step - loss: 0.2570 - mae: 0.1851 - rmse: 0.2590 - val_loss: 0.4106 - val_mae: 0.3158 - val_rmse: 0.4156
# Epoch 28/50
# 482/482 [==============================] - 1s 1ms/step - loss: 0.2600 - mae: 0.1894 - rmse: 0.2619 - val_loss: 0.4110 - val_mae: 0.3164 - val_rmse: 0.4160
# Epoch 29/50
# 482/482 [==============================] - 1s 1ms/step - loss: 0.2600 - mae: 0.1902 - rmse: 0.2620 - val_loss: 0.4280 - val_mae: 0.3328 - val_rmse: 0.4331
# Epoch 30/50
# 482/482 [==============================] - 1s 1ms/step - loss: 0.2620 - mae: 0.1914 - rmse: 0.2639 - val_loss: 0.4236 - val_mae: 0.3276 - val_rmse: 0.4286
# Epoch 31/50
# 482/482 [==============================] - 1s 1ms/step - loss: 0.2608 - mae: 0.1903 - rmse: 0.2628 - val_loss: 0.4221 - val_mae: 0.3262 - val_rmse: 0.4273
# Epoch 32/50
# 482/482 [==============================] - 1s 1ms/step - loss: 0.2598 - mae: 0.1891 - rmse: 0.2617 - val_loss: 0.4191 - val_mae: 0.3229 - val_rmse: 0.4242
# Epoch 33/50
# 482/482 [==============================] - 1s 2ms/step - loss: 0.2566 - mae: 0.1842 - rmse: 0.2586 - val_loss: 0.4095 - val_mae: 0.3138 - val_rmse: 0.4145
# Epoch 34/50
# 482/482 [==============================] - 1s 1ms/step - loss: 0.2562 - mae: 0.1840 - rmse: 0.2582 - val_loss: 0.4211 - val_mae: 0.3244 - val_rmse: 0.4262
# Epoch 35/50
# 482/482 [==============================] - 1s 1ms/step - loss: 0.2563 - mae: 0.1844 - rmse: 0.2582 - val_loss: 0.4211 - val_mae: 0.3244 - val_rmse: 0.4262
# Epoch 36/50
# 482/482 [==============================] - 1s 1ms/step - loss: 0.2562 - mae: 0.1841 - rmse: 0.2581 - val_loss: 0.4198 - val_mae: 0.3227 - val_rmse: 0.4249
# Epoch 37/50
# 482/482 [==============================] - 1s 1ms/step - loss: 0.2585 - mae: 0.1878 - rmse: 0.2604 - val_loss: 0.4198 - val_mae: 0.3229 - val_rmse: 0.4248
# Epoch 38/50
# 482/482 [==============================] - 1s 1ms/step - loss: 0.2569 - mae: 0.1848 - rmse: 0.2588 - val_loss: 0.4100 - val_mae: 0.3141 - val_rmse: 0.4149
# Epoch 39/50
# 482/482 [==============================] - 1s 1ms/step - loss: 0.2577 - mae: 0.1856 - rmse: 0.2597 - val_loss: 0.4329 - val_mae: 0.3375 - val_rmse: 0.4380
# Epoch 40/50
# 482/482 [==============================] - 1s 2ms/step - loss: 0.2608 - mae: 0.1894 - rmse: 0.2627 - val_loss: 0.4108 - val_mae: 0.3151 - val_rmse: 0.4157
# Epoch 41/50
# 482/482 [==============================] - 1s 1ms/step - loss: 0.2573 - mae: 0.1856 - rmse: 0.2593 - val_loss: 0.4317 - val_mae: 0.3362 - val_rmse: 0.4368
# Epoch 42/50
# 482/482 [==============================] - 1s 1ms/step - loss: 0.2562 - mae: 0.1839 - rmse: 0.2581 - val_loss: 0.4097 - val_mae: 0.3134 - val_rmse: 0.4146
# Epoch 43/50
# 482/482 [==============================] - 1s 1ms/step - loss: 0.2568 - mae: 0.1850 - rmse: 0.2588 - val_loss: 0.4183 - val_mae: 0.3206 - val_rmse: 0.4233
# Epoch 44/50
# 482/482 [==============================] - 1s 1ms/step - loss: 0.2560 - mae: 0.1844 - rmse: 0.2580 - val_loss: 0.4192 - val_mae: 0.3215 - val_rmse: 0.4243
# Epoch 45/50
# 482/482 [==============================] - 1s 1ms/step - loss: 0.2562 - mae: 0.1842 - rmse: 0.2581 - val_loss: 0.4196 - val_mae: 0.3218 - val_rmse: 0.4246
# Epoch 46/50
# 482/482 [==============================] - 1s 2ms/step - loss: 0.2563 - mae: 0.1841 - rmse: 0.2583 - val_loss: 0.4183 - val_mae: 0.3204 - val_rmse: 0.4233
# Epoch 47/50
# 482/482 [==============================] - 1s 1ms/step - loss: 0.2571 - mae: 0.1850 - rmse: 0.2590 - val_loss: 0.4301 - val_mae: 0.3337 - val_rmse: 0.4351
# Epoch 48/50
# 482/482 [==============================] - 1s 1ms/step - loss: 0.2590 - mae: 0.1879 - rmse: 0.2609 - val_loss: 0.4266 - val_mae: 0.3304 - val_rmse: 0.4316
# Epoch 49/50
# 482/482 [==============================] - 1s 1ms/step - loss: 0.2599 - mae: 0.1883 - rmse: 0.2618 - val_loss: 0.4094 - val_mae: 0.3126 - val_rmse: 0.4143
# Epoch 50/50
# 482/482 [==============================] - 1s 1ms/step - loss: 0.2566 - mae: 0.1845 - rmse: 0.2585 - val_loss: 0.4329 - val_mae: 0.3372 - val_rmse: 0.4380
# 39/39 [==============================] - 0s 1ms/step - loss: 0.5189 - mae: 0.3467 - rmse: 0.5189
# /tmp/ipykernel_95071/2339410507.py:50: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(3,1,i+1)

# %%
forecasts = forecast(model, bd, timesteps, multisteps, scaler)
plot_forecast(bd, forecasts)
# Out:
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step

# %%
forecasts
# Out:
# [1.9345279, 1.8553731, 1.7495275, 1.6249233, 1.4823123, 1.3332348, 1.1915627]

# %%
model.compile(loss=rmse, optimizer=tf.keras.optimizers.Adam(), metrics=['mae', rmse])
model.fit(X, y, epochs=epochs, batch_size=batch_size, shuffle=False)

# %%
# plot_learning_curves(hist_list, epochs)

# %%
forecasts = forecast(model, bd, timesteps, multisteps, scaler)

# %%
print(forecasts)

# %%
plot_forecast(bd, forecasts)
